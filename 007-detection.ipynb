# %% [markdown]
# # The Nature Conservancy Fisheries Monitoring

# %% [markdown]
# https://www.kaggle.com/c/the-nature-conservancy-fisheries-monitoring

# %%
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf

print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# # Загружаем разметку

# %%
import os
import json
from glob import glob

TRAIN_PREFIX = 'train'

def load_annotations():
    boxes = dict()
    for path in glob('datasets/*.json'):
        label = os.path.basename(path).split('.', 1)[0].lower()
        with open(path) as src:
            for annotation in json.load(src):
                basename = os.path.basename(annotation['filename'])
                annotation['filename'] = f'{TRAIN_PREFIX}/{annotation["filename"]}'
                for rect in annotation['annotations']:
                    rect['x'] += rect['width'] / 2
                    rect['y'] += rect['height'] / 2
                if os.path.isfile(annotation['filename']):
                    boxes.setdefault(label, []).append(annotation)
    return boxes

def draw_boxes(annotation, rectangles=None, image_size=None):
    
    def _draw(img, rectangles, scale_x, scale_y, color=(0, 255, 0)):
        for rect in rectangles:
            pt1 = (int((rect['x'] - rect['width'] / 2) * scale_x),
                   int((rect['y'] - rect['height'] / 2) * scale_y))
            pt2 = (int((rect['x'] + rect['width'] / 2) * scale_x),
                   int((rect['y'] + rect['height'] / 2) * scale_y))
            img = cv2.rectangle(img.copy(), pt1, pt2, 
                                color=color, thickness=4)
        return img
    
    scale_x, scale_y = 1., 1.
    
    img = cv2.imread(annotation['filename'], cv2.IMREAD_COLOR)[...,::-1]
    if image_size is not None:
        scale_x = 1. * image_size[0] / img.shape[1]
        scale_y = 1. * image_size[1] / img.shape[0]
        img = cv2.resize(img, image_size)
        
    img = _draw(img, annotation.get('annotations', []), scale_x, scale_y)
    
    if rectangles is not None:
        img = _draw(img, rectangles, 1., 1., (255, 0, 0))

    return img

# %% [markdown]
# ### Визуализируем разметку

# %%
boxes = load_annotations()  # загружаем разметку детекций
boxes
# Out:
# {'yft': [{'annotations': [{'class': 'YFT',
#      'height': 263.0,
#      'width': 393.0,
#      'x': 753.5,
#      'y': 596.5}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00004.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 180.0,
#      'width': 187.0,
#      'x': 459.5,
#      'y': 392.0}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00014.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 233.0,
#      'width': 130.0,
#      'x': 886.0,
#      'y': 514.5}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00021.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 141.0,
#      'width': 221.0,
#      'x': 352.5,
#      'y': 443.5}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00023.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 137.0,
#      'width': 149.0,
#      'x': 541.5,
#      'y': 210.5}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00047.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 69.0,
#      'width': 145.0,
#      'x': 475.5,
#      'y': 365.5}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00052.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 182.0,
#      'width': 394.0,
#      'x': 799.0,
#      'y': 209.0},
#     {'class': 'YFT', 'height': 81.0, 'width': 343.0, 'x': 482.5, 'y': 122.5}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00061.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 318.0,
#      'width': 246.0,
#      'x': 868.0,
#      'y': 701.0}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00069.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 78.0,
#      'width': 187.0,
#      'x': 536.5,
#      'y': 488.0}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00092.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 172.40371805949064,
#      'width': 169.86213990627948,
#      'x': 843.1685523278036,
#      'y': 403.8991281811408}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00093.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 256.69939347432756,
#      'width': 389.7086501590451,
#      'x': 939.960320329262,
#      'y': 233.8251900954271}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00114.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 271.94886239359454,
#      'width': 338.0298943770848,
#      'x': 620.1450693835241,
#      'y': 587.951746109516}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00116.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 163.50819452325152,
#      'width': 267.2893024460407,
#      'x': 147.19973470681325,
#      'y': 329.98156355858276}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00118.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 136.82162391453426,
#      'width': 232.13080465995301,
#      'x': 945.0434766356846,
#      'y': 519.5409341522487}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00137.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 111.82943874129126,
#      'width': 276.6084223411483,
#      'x': 895.2709044686325,
#      'y': 432.4918824047664}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00139.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 144.44635837416783,
#      'width': 291.01069854267826,
#      'x': 156.51885460192085,
#      'y': 315.7910855364871}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00184.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 224.08247384145096,
#      'width': 120.30136591866176,
#      'x': 888.2815645473017,
#      'y': 519.5409341522487}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00194.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 187.6531869787576,
#      'width': 363.02207955032793,
#      'x': 950.3384311215411,
#      'y': 234.88418099259837},
#     {'class': 'YFT',
#      'height': 191.04195784970582,
#      'width': 368.10523585675026,
#      'x': 369.5878231127901,
#      'y': 125.17272404564983}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00214.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 266.01851336943514,
#      'width': 404.9581190783121,
#      'x': 256.69939347432756,
#      'y': 342.26585796577007}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00217.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 58.03270116498828,
#      'width': 151.22390011606421,
#      'x': 471.25094924123664,
#      'y': 436.9396441728859}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00218.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 266.86570608717216,
#      'width': 394.7918064654674,
#      'x': 956.0569819662662,
#      'y': 268.1364951637778},
#     {'class': 'YFT',
#      'height': 176.63968164817587,
#      'width': 255.42860439772198,
#      'x': 711.4300847196916,
#      'y': 171.76832352118782}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00221.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 79.63611546728316,
#      'width': 207.98581220444692,
#      'x': 281.90337682700493,
#      'y': 442.2345986587425}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00222.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 313.46130556271015,
#      'width': 165.62617631759423,
#      'x': 593.2467005953725,
#      'y': 546.0157065815317}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00238.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 158.00144185796069,
#      'width': 196.54871051499663,
#      'x': 812.8814126687039,
#      'y': 397.12158643924437}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00250.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 295.2466621313635,
#      'width': 208.40940856331542,
#      'x': 528.2246595090535,
#      'y': 522.5061086643284}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00253.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 168.59135082967387,
#      'width': 385.4726865703598,
#      'x': 409.61767902586587,
#      'y': 329.13437084084575}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00276.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 157.57784549909218,
#      'width': 468.92116926745973,
#      'x': 424.6553497656986,
#      'y': 408.77048630812885}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00279.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 160.11942365230334,
#      'width': 273.64324782906874,
#      'x': 706.9823229515721,
#      'y': 158.00144185796069},
#     {'class': 'YFT',
#      'height': 315.15569099818435,
#      'width': 474.00432557388206,
#      'x': 856.300039452728,
#      'y': 347.34901427219245}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00284.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 98.69795161636688,
#      'width': 196.5487105149967,
#      'x': 352.4321705786147,
#      'y': 433.1272769430692}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00286.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 99.12154797523539,
#      'width': 235.51957553090116,
#      'x': 341.418665248033,
#      'y': 457.06047121914094},
#     {'class': 'YFT',
#      'height': 157.15424914022367,
#      'width': 77.51813367294051,
#      'x': 142.96377111812797,
#      'y': 562.32416639797}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00287.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 263.476935216224,
#      'width': 381.6603193405431,
#      'x': 722.4435900502733,
#      'y': 610.8259494884164}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00298.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 194.00713236178547,
#      'width': 669.7058433711418,
#      'x': 941.442907585302,
#      'y': 650.644007222058}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00312.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 160.54302001117188,
#      'width': 180.45204887799264,
#      'x': 1072.1223842962427,
#      'y': 195.06612325895685}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00313.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 71.58778464878105,
#      'width': 182.99362703120386,
#      'x': 534.5786048920814,
#      'y': 486.5004181605036}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00333.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 333.7939307883995,
#      'width': 288.0455240305986,
#      'x': 573.1258735491174,
#      'y': 568.4663136015636}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00362.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 331.67594899405685,
#      'width': 474.00432557388217,
#      'x': 859.6888103236762,
#      'y': 344.1720415806784},
#     {'class': 'YFT',
#      'height': 152.49468919266985,
#      'width': 253.31062260337933,
#      'x': 712.9126719757314,
#      'y': 152.91828555153836}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00370.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 72.43497736651818,
#      'width': 151.22390011606421,
#      'x': 393.73281556829613,
#      'y': 442.8699931970453}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00372.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 171.98012170062213,
#      'width': 467.2267838319856,
#      'x': 424.2317534068301,
#      'y': 408.77048630812885}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00378.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 330.4051599174513,
#      'width': 151.64749647493284,
#      'x': 600.2360405167033,
#      'y': 552.3696519645596}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00395.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 224.92966655918798,
#      'width': 380.81312662280607,
#      'x': 666.9524670384963,
#      'y': 522.0825123054599}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00404.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 122.84294407187292,
#      'width': 227.4712447123992,
#      'x': 504.7150615918503,
#      'y': 462.1436275255633},
#     {'class': 'YFT',
#      'height': 147.41153288624753,
#      'width': 70.31699557217553,
#      'x': 155.45986370474952,
#      'y': 596.4236732868865}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00420.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 64.38664654801613,
#      'width': 130.4676785315064,
#      'x': 341.84226160690156,
#      'y': 443.5053877353481}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00436.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 157.1542491402236,
#      'width': 206.29142676897277,
#      'x': 813.0932108481381,
#      'y': 396.6979900803758}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00437.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 172.82731441835918,
#      'width': 391.82663195338773,
#      'x': 409.4058808464316,
#      'y': 334.2175271472681}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00439.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 88.53163900352223,
#      'width': 139.36320206774548,
#      'x': 336.97090347991343,
#      'y': 446.68236042686203}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00440.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 150.80030375719565,
#      'width': 221.11729932937124,
#      'x': 454.09529670706127,
#      'y': 447.3177549651648}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00470.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 74.12936280199227,
#      'width': 154.189074628144,
#      'x': 518.905539613946,
#      'y': 486.5004181605036}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00477.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 285.92754223625593,
#      'width': 496.4549325939141,
#      'x': 852.6994704023455,
#      'y': 347.56081245162665},
#     {'class': 'YFT',
#      'height': 157.57784549909218,
#      'width': 270.25447695812045,
#      'x': 717.1486355644167,
#      'y': 156.3070564224866}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00501.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 307.1073601796823,
#      'width': 427.408726098344,
#      'x': 851.6404795051741,
#      'y': 661.4457143732054}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00506.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 116.91259504771352,
#      'width': 135.12723847906022,
#      'x': 691.9446522117394,
#      'y': 414.2772389734197}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00522.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 90.22602443899632,
#      'width': 194.43072872065403,
#      'x': 456.8486730397067,
#      'y': 452.1891130921529}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00535.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 218.9993175350286,
#      'width': 359.2097123205112,
#      'x': 368.95242857448727,
#      'y': 302.23600205269423}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00536.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 181.72283795459828,
#      'width': 262.6297424984869,
#      'x': 461.29643480782624,
#      'y': 462.3554257049976}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00539.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 124.1137331484785,
#      'width': 232.13080465995296,
#      'x': 506.19764884789015,
#      'y': 464.47340749934017},
#     {'class': 'YFT',
#      'height': 138.9396057088769,
#      'width': 72.43497736651818,
#      'x': 156.0952582430523,
#      'y': 592.6113060570697}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00540.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 189.77116877310021,
#      'width': 497.72572167051953,
#      'x': 587.3163515712131,
#      'y': 156.7306527813551},
#     {'class': 'YFT',
#      'height': 109.28786058808004,
#      'width': 252.03983352677372,
#      'x': 228.10663925070196,
#      'y': 393.09742102999337}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00566.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 258.39377890980165,
#      'width': 218.99931753502864,
#      'x': 617.3916930508785,
#      'y': 134.28004576132315}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00572.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 288.8927167483356,
#      'width': 252.4634298856423,
#      'x': 864.1365720917956,
#      'y': 682.837330496066}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00573.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 283.3859640830448,
#      'width': 305.8365711030767,
#      'x': 173.25091077722766,
#      'y': 451.34192037441585}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00641.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 243.9915027082717,
#      'width': 274.49044054680564,
#      'x': 780.6880893946959,
#      'y': 563.3831572951412}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00647.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 140.63399114435106,
#      'width': 261.3589534218813,
#      'x': 254.36961350055066,
#      'y': 399.4513664130213}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00677.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 259.66456798640723,
#      'width': 339.3006834536904,
#      'x': 627.5580056637232,
#      'y': 587.3163515712131}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00680.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 171.132928982885,
#      'width': 310.91972740949905,
#      'x': 637.0889237382651,
#      'y': 551.5224592468226}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00694.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 227.47124471239917,
#      'width': 393.5210173888619,
#      'x': 370.43501583052716,
#      'y': 303.9303874881683}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00696.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 121.99575135413579,
#      'width': 214.76335394634333,
#      'x': 514.8813742046949,
#      'y': 464.2616093199059},
#     {'class': 'YFT',
#      'height': 148.25872560398454,
#      'width': 68.1990137778329,
#      'x': 154.4008728075782,
#      'y': 600.2360405167033}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00704.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 182.5700306723353,
#      'width': 95.30918074541864,
#      'x': 445.835167709125,
#      'y': 434.3980660196748}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00738.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 155.88346006361803,
#      'width': 160.9666163700404,
#      'x': 518.4819432550775,
#      'y': 90.2260244389963},
#     {'class': 'YFT',
#      'height': 82.1776936204943,
#      'width': 149.9531110394587,
#      'x': 1078.4763296792705,
#      'y': 102.51031884618361}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00739.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 231.28361194221588,
#      'width': 448.1649476829019,
#      'x': 366.8344467801447,
#      'y': 416.39522076776234}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00743.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 199.9374813859449,
#      'width': 127.50250401942674,
#      'x': 470.40375652349957,
#      'y': 142.7519729386937}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00752.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 191.0419578497058,
#      'width': 329.1343708408458,
#      'x': 794.8785674167915,
#      'y': 526.7420722530137}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00769.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 119.03057684205618,
#      'width': 149.10591832172162,
#      'x': 526.5302740735794,
#      'y': 454.730691245364}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00778.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 238.06115368411236,
#      'width': 440.5402132232684,
#      'x': 677.3305778307752,
#      'y': 618.0270875891813}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00783.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 142.32837657982515,
#      'width': 457.90766393687807,
#      'x': 384.8372920320571,
#      'y': 329.1343708408457}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00796.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 259.66456798640723,
#      'width': 418.5132025621051,
#      'x': 937.418742176051,
#      'y': 276.39662416171404},
#     {'class': 'YFT',
#      'height': 169.86213990627945,
#      'width': 264.324127933961,
#      'x': 710.3710938225204,
#      'y': 157.78964367852643}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00801.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 243.14430999053462,
#      'width': 302.44780023212866,
#      'x': 909.4613824907282,
#      'y': 613.7911240004961}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00803.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 82.60128997936283,
#      'width': 168.5913508296739,
#      'x': 368.95242857448727,
#      'y': 437.78683689062296},
#     {'class': 'YFT',
#      'height': 157.15424914022356,
#      'width': 109.71145694694859,
#      'x': 180.6638470574269,
#      'y': 609.3433622323765}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00806.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 417.24241348549947,
#      'width': 269.4072842403834,
#      'x': 335.48831622387365,
#      'y': 367.4698413184475}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00807.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 104.62830064052628,
#      'width': 167.32056175306832,
#      'x': 444.98797499138794,
#      'y': 447.5295531445991}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00815.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 197.81949959160227,
#      'width': 403.6873300017065,
#      'x': 792.3369892635803,
#      'y': 230.64821740391312}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00827.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 91.92040987447047,
#      'width': 171.55652534175357,
#      'x': 448.3767458623362,
#      'y': 448.8003422212047}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00871.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 130.0440821726379,
#      'width': 228.31843743013616,
#      'x': 498.7847125676909,
#      'y': 463.20261842273464}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00872.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 97.4271625397613,
#      'width': 199.5138850270763,
#      'x': 538.1791739424639,
#      'y': 86.41365720917958},
#     {'class': 'YFT',
#      'height': 101.66312612844655,
#      'width': 144.02276201529935,
#      'x': 1080.5943114736133,
#      'y': 96.15637346315569}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00890.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 344.80743611898123,
#      'width': 426.1379370217385,
#      'x': 418.513202562105,
#      'y': 344.38383976011266}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00891.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 249.07465901469402,
#      'width': 262.62974249848696,
#      'x': 812.0342199509669,
#      'y': 578.6326262144082}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00896.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 204.5970413334987,
#      'width': 398.6041736952842,
#      'x': 795.7257601345286,
#      'y': 232.3426028393872}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00900.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 126.23171494282116,
#      'width': 253.3106226033794,
#      'x': 489.25379449314903,
#      'y': 444.77617681195363}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00916.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 199.93748138594492,
#      'width': 87.68444628578516,
#      'x': 460.6610402695234,
#      'y': 430.7974969692923}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00925.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 258.39377890980165,
#      'width': 288.0455240305986,
#      'x': 607.8607749763366,
#      'y': 582.8685898030935}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00945.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 108.86426422921153,
#      'width': 183.41722339007234,
#      'x': 339.51248163312465,
#      'y': 451.76551673328436}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00955.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 68.62261013670144,
#      'width': 177.48687436591297,
#      'x': 532.672421277173,
#      'y': 486.28861998106936}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00958.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 256.275797115459,
#      'width': 800.5971182615165,
#      'x': 800.5971182615165,
#      'y': 619.5096748452212}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00968.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 164.77898359985713,
#      'width': 376.57716303412076,
#      'x': 919.8394932830071,
#      'y': 213.2807666903035}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00969.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 211.37458307539515,
#      'width': 242.29711727279764,
#      'x': 124.53732950734704,
#      'y': 403.05193546340377}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00997.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 141.48118386208813,
#      'width': 143.17556929756222,
#      'x': 510.8572087954439,
#      'y': 95.73277710428718},
#     {'class': 'YFT',
#      'height': 93.19119895107602,
#      'width': 151.64749647493284,
#      'x': 1081.0179078324818,
#      'y': 96.1563734631557}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01007.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 73.2821700842552,
#      'width': 170.7093326240165,
#      'x': 526.3184758941452,
#      'y': 485.22962908389803}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01008.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 243.9915027082717,
#      'width': 437.15144235232026,
#      'x': 751.036344273899,
#      'y': 623.5338402544721}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01064.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 287.19833131286157,
#      'width': 175.3688925715703,
#      'x': 606.5899858997311,
#      'y': 517.6347505373403}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01076.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 180.02845251912413,
#      'width': 234.24878645429555,
#      'x': 670.3412379094445,
#      'y': 414.9126335117225}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01087.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 124.96092586621563,
#      'width': 233.4015937365586,
#      'x': 502.1734834386391,
#      'y': 465.3206002170773}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01113.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 111.40584238242263,
#      'width': 227.47124471239914,
#      'x': 481.4172618540813,
#      'y': 458.96665483404934}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01143.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 201.20827046255044,
#      'width': 241.02632819619203,
#      'x': 813.0932108481381,
#      'y': 628.8287947403288}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01156.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 266.0185133694351,
#      'width': 337.18270165934774,
#      'x': 631.5821710729742,
#      'y': 557.4528082709819}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01174.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 152.49468919266985,
#      'width': 291.01069854267826,
#      'x': 261.99434796018414,
#      'y': 412.5828535379456}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01189.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 235.5195755309012,
#      'width': 570.1606990370377,
#      'x': 287.62192767173,
#      'y': 706.9823229515721}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01190.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 161.81380908777743,
#      'width': 222.38808840597684,
#      'x': 115.00641143280517,
#      'y': 427.8323224572126}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01199.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 185.1116088255465,
#      'width': 94.03839166881306,
#      'x': 443.0817913764796,
#      'y': 435.24525873741186}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01201.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 230.43641922447893,
#      'width': 121.99575135413579,
#      'x': 889.9759499827759,
#      'y': 518.058346896209}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01217.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 87.26084992691665,
#      'width': 162.6610018055145,
#      'x': 505.3504561301531,
#      'y': 459.1784530134836}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01233.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 150.80030375719576,
#      'width': 257.122989833196,
#      'x': 787.6774293160265,
#      'y': 557.8764046298505}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01235.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 167.32056175306826,
#      'width': 292.28148761928384,
#      'x': 307.9545528974194,
#      'y': 384.4136956731885}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01241.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 127.50250401942674,
#      'width': 132.58566032584906,
#      'x': 686.01430318758,
#      'y': 398.81597187471846}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01254.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 161.39021272890886,
#      'width': 246.95667722035148,
#      'x': 793.6077783401859,
#      'y': 572.0668826519461}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01270.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 229.16563014787334,
#      'width': 127.50250401942674,
#      'x': 890.6113445210788,
#      'y': 518.6937414345117}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01292.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 277.879211417754,
#      'width': 443.5053877353481,
#      'x': 720.7492046147993,
#      'y': 639.6305018914762}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01301.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 285.0803495185189,
#      'width': 470.19195834406537,
#      'x': 332.9467380706625,
#      'y': 475.91050918879046}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01308.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 232.55440101882147,
#      'width': 443.9289840942166,
#      'x': 340.1478761714274,
#      'y': 451.34192037441585}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01323.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 129.19688945490083,
#      'width': 57.60910480611972,
#      'x': 581.1742043676195,
#      'y': 273.00785329076587},
#     {'class': 'YFT',
#      'height': 80.90690454388874,
#      'width': 155.03626734588101,
#      'x': 908.614189772991,
#      'y': 347.5608124516267}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01329.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 295.6702584902321,
#      'width': 246.53308086148297,
#      'x': 861.1713975797161,
#      'y': 683.6845232138031}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01335.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 254.58141167998494,
#      'width': 365.5636577035391,
#      'x': 195.48971961782536,
#      'y': 358.57431778220837}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01340.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 170.70933262401655,
#      'width': 116.91259504771358,
#      'x': 402.41654092510095,
#      'y': 403.05193546340377}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01346.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 315.57928735705286,
#      'width': 495.6077398761769,
#      'x': 845.9219286604491,
#      'y': 342.9012525040729}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01358.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 72.01138100764962,
#      'width': 139.3632020677455,
#      'x': 323.4158199961206,
#      'y': 464.6852056787744}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01368.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 193.58353600291701,
#      'width': 324.8984072521604,
#      'x': 643.2310709418587,
#      'y': 553.8522392205995}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01370.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 83.87207905596841,
#      'width': 216.88133574068598,
#      'x': 515.5167687429978,
#      'y': 398.1805773364157}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01372.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 249.92185173243115,
#      'width': 417.24241348549936,
#      'x': 406.86430269322045,
#      'y': 402.8401372839695}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01375.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 195.70151779725964,
#      'width': 381.6603193405431,
#      'x': 378.48334664902916,
#      'y': 335.48831622387365}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01380.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 104.62830064052622,
#      'width': 180.87564523686117,
#      'x': 338.24169255651907,
#      'y': 453.03630580989}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01385.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 185.95880154328347,
#      'width': 94.88558438655014,
#      'x': 440.96380958213695,
#      'y': 431.43289150759506}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01403.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 79.63611546728315,
#      'width': 207.1386194867099,
#      'x': 555.1230282972051,
#      'y': 135.55083483792873}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01410.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 88.10804264465372,
#      'width': 230.86001558334738,
#      'x': 323.4158199961206,
#      'y': 437.9986350700573},
#     {'class': 'YFT',
#      'height': 165.62617631759423,
#      'width': 73.70576644312376,
#      'x': 139.786798426614,
#      'y': 561.0533773213645}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01415.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 263.90053157509254,
#      'width': 369.7996212922243,
#      'x': 625.8636202282491,
#      'y': 549.1926792730457}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01429.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 229.5892265067418,
#      'width': 117.7597877654506,
#      'x': 892.0939317771185,
#      'y': 517.6347505373403}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01456.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 193.15993964404845,
#      'width': 392.25022831225635,
#      'x': 798.0555401083054,
#      'y': 231.70720830108445},
#     {'class': 'YFT',
#      'height': 82.60128997936282,
#      'width': 374.88277759864667,
#      'x': 475.0633164710533,
#      'y': 125.59632040451834}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01469.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 226.20045563579367,
#      'width': 672.6710178832213,
#      'x': 937.8423385349195,
#      'y': 635.394538302791}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01472.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 124.53732950734701,
#      'width': 282.1151750064392,
#      'x': 239.75553911958644,
#      'y': 384.62549385262275},
#     {'class': 'YFT',
#      'height': 197.81949959160224,
#      'width': 507.89203428336424,
#      'x': 583.9275807002649,
#      'y': 155.24806552531527}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01492.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 149.95311103945863,
#      'width': 291.4342949015468,
#      'x': 262.62974249848696,
#      'y': 413.00644989681416}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01498.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 125.80811858395259,
#      'width': 244.83869542600877,
#      'x': 501.96168525920484,
#      'y': 463.62621478160315}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01516.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 123.26654043074143,
#      'width': 231.28361194221594,
#      'x': 504.9268597712846,
#      'y': 465.74419657594575}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01518.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 227.4712447123992,
#      'width': 221.96449204710837,
#      'x': 841.2623687128953,
#      'y': 663.563696167548}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01521.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 102.08672248731509,
#      'width': 183.84081974894082,
#      'x': 480.35827095690996,
#      'y': 89.16703354182499},
#     {'class': 'YFT',
#      'height': 89.37883172125926,
#      'width': 151.64749647493272,
#      'x': 1078.4763296792705,
#      'y': 100.18053887240671}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01532.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 252.0398335267738,
#      'width': 238.90834640184937,
#      'x': 755.6959042214528,
#      'y': 667.7996597562333}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01535.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 149.10591832172162,
#      'width': 282.5387713653077,
#      'x': 248.86286083525977,
#      'y': 413.8536426145512}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01539.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 124.11373314847845,
#      'width': 263.05333885735547,
#      'x': 379.75413572563474,
#      'y': 457.69586575744376}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01573.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 156.7306527813551,
#      'width': 401.14575184849537,
#      'x': 489.0419963137148,
#      'y': 409.19408266699736}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01606.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 96.57996982202422,
#      'width': 171.132928982885,
#      'x': 494.76054715843986,
#      'y': 85.142868132574},
#     {'class': 'YFT',
#      'height': 96.57996982202424,
#      'width': 154.6126709870124,
#      'x': 1077.8409351409678,
#      'y': 102.51031884618362}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01610.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 148.68232196285305,
#      'width': 377.00075939298927,
#      'x': 474.00432557388206,
#      'y': 187.0177924404548}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01623.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 166.89696539419975,
#      'width': 79.63611546728316,
#      'x': 857.7826267087678,
#      'y': 166.47336903533125}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01625.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 192.7363432851799,
#      'width': 480.35827095691,
#      'x': 583.7157825208307,
#      'y': 156.51885460192085},
#     {'class': 'YFT',
#      'height': 115.64180597110794,
#      'width': 292.7050839781524,
#      'x': 250.5572462707339,
#      'y': 389.9204483384794}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01634.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 263.0533388573554,
#      'width': 238.48475004298086,
#      'x': 787.6774293160265,
#      'y': 571.6432862930776}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01658.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 99.54514433410395,
#      'width': 244.83869542600877,
#      'x': 471.8863437795394,
#      'y': 451.34192037441585}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01662.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 85.5664644914425,
#      'width': 238.06115368411236,
#      'x': 327.4399854053716,
#      'y': 438.8458277877943},
#     {'class': 'YFT',
#      'height': 165.62617631759417,
#      'width': 76.67094095520346,
#      'x': 141.26938568265388,
#      'y': 557.2410100915477}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01675.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 127.50250401942668,
#      'width': 255.42860439772198,
#      'x': 490.7363817491889,
#      'y': 444.5643786325194},
#     {'class': 'YFT',
#      'height': 187.2295906198891,
#      'width': 49.98437034648623,
#      'x': 155.036267345881,
#      'y': 572.2786808313804}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01691.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 276.18482598227985,
#      'width': 290.1635058249412,
#      'x': 148.89412014228733,
#      'y': 427.8323224572126}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01700.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 67.35182106009586,
#      'width': 130.0440821726379,
#      'x': 335.7001144033079,
#      'y': 440.3284150438341}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01704.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 77.94173003180907,
#      'width': 181.29924159572977,
#      'x': 532.4606230977388,
#      'y': 484.5942345455952}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01709.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 189.77116877310027,
#      'width': 352.0085742197462,
#      'x': 497.9375198499539,
#      'y': 481.62906003351554}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01712.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 235.51957553090125,
#      'width': 437.99863507005716,
#      'x': 790.0072092898034,
#      'y': 618.4506839480499}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01718.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 296.9410475668376,
#      'width': 441.811002299874,
#      'x': 675.8479905747354,
#      'y': 636.8771255588308}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01721.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 87.68444628578516,
#      'width': 240.60273183732352,
#      'x': 243.14430999053468,
#      'y': 520.3881268699859}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01727.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 215.1869503052119,
#      'width': 171.132928982885,
#      'x': 834.4848269709988,
#      'y': 385.8962829292284}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01742.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 125.80811858395259,
#      'width': 246.53308086148286,
#      'x': 499.4201071059937,
#      'y': 464.04981114047166},
#     {'class': 'YFT',
#      'height': 151.22390011606421,
#      'width': 71.16418828991259,
#      'x': 157.57784549909215,
#      'y': 591.5523151598984}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01747.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 327.4399854053716,
#      'width': 623.9574366133406,
#      'x': 767.7684004492057,
#      'y': 265.3831188311324}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01749.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 158.00144185796069,
#      'width': 236.79036460750672,
#      'x': 905.0136207226086,
#      'y': 409.40588084643167}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01767.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 255.00500803885348,
#      'width': 289.73990946607273,
#      'x': 772.6397585761938,
#      'y': 558.7235973475875}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01769.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 104.20470428165771,
#      'width': 183.4172233900723,
#      'x': 342.4776561452043,
#      'y': 448.58854404177043}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01779.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 267.7128988049093,
#      'width': 236.3667682486382,
#      'x': 625.2282256899463,
#      'y': 545.1685138637947}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01783.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 173.67450713609617,
#      'width': 672.6710178832213,
#      'x': 942.9254948413418,
#      'y': 659.9631271171656}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01784.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 284.65675315965035,
#      'width': 186.38239790215198,
#      'x': 526.953870432448,
#      'y': 517.6347505373403}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01808.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 74.12936280199227,
#      'width': 175.3688925715703,
#      'x': 436.72784599345164,
#      'y': 447.10595678573054},
#     {'class': 'YFT',
#      'height': 203.3262522568931,
#      'width': 57.185508447251195,
#      'x': 141.69298204152238,
#      'y': 571.0078917547748}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01817.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 135.5508348379288,
#      'width': 199.0902886682078,
#      'x': 958.5985601194773,
#      'y': 518.058346896209}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01829.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 272.79605511133155,
#      'width': 304.98937838533965,
#      'x': 572.7022771902489,
#      'y': 536.6965866864241}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01835.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 269.8308805992519,
#      'width': 339.3006834536904,
#      'x': 617.815289409747,
#      'y': 549.6162756319142}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01840.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 199.93748138594486,
#      'width': 433.33907512250346,
#      'x': 804.6212836707675,
#      'y': 227.47124471239914},
#     {'class': 'YFT',
#      'height': 91.49681351560191,
#      'width': 314.7320946393158,
#      'x': 499.2083089265594,
#      'y': 121.99575135413588}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01842.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 193.1599396440484,
#      'width': 243.14430999053468,
#      'x': 790.0072092898035,
#      'y': 546.0157065815317}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01848.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 252.0398335267738,
#      'width': 127.92610037829525,
#      'x': 389.2850538001766,
#      'y': 431.8564878664636}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01854.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 135.12723847906022,
#      'width': 250.76904445016814,
#      'x': 372.764795804304,
#      'y': 414.9126335117225}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01861.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 225.3532629180565,
#      'width': 431.2210933281608,
#      'x': 262.62974249848696,
#      'y': 462.14362752556326}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01876.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 76.67094095520343,
#      'width': 219.8465102527657,
#      'x': 279.36179867379377,
#      'y': 441.1756077615712}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01886.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 225.3532629180565,
#      'width': 460.87283844895774,
#      'x': 376.15356667525225,
#      'y': 384.20189749375425}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01898.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 235.94317188976976,
#      'width': 443.9289840942166,
#      'x': 686.2261013670143,
#      'y': 615.6973076154045}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01938.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 72.43497736651818,
#      'width': 146.1407438096419,
#      'x': 514.8813742046949,
#      'y': 478.02849098313305}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01953.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 171.5565253417536,
#      'width': 268.5600915226463,
#      'x': 737.481260790106,
#      'y': 275.97302780284554}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01959.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 134.28004576132315,
#      'width': 250.76904445016817,
#      'x': 490.9481799286232,
#      'y': 444.14078227365087}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01972.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 299.4826257200488,
#      'width': 436.30424963458324,
#      'x': 933.1827785873656,
#      'y': 262.8415406779212}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01973.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 216.88133574068598,
#      'width': 194.00713236178552,
#      'x': 607.4371786174681,
#      'y': 490.52458356975467}],
#    'class': 'image',
#    'filename': 'train/YFT/img_01974.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 224.08247384145096,
#      'width': 379.1187411873319,
#      'x': 958.386761940043,
#      'y': 219.6347120733314},
#     {'class': 'YFT',
#      'height': 151.64749647493278,
#      'width': 354.5501523729573,
#      'x': 377.6361539312921,
#      'y': 108.86426422921153}],
#    'class': 'image',
#    'filename': 'train/YFT/img_02014.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 183.41722339007237,
#      'width': 182.5700306723353,
#      'x': 686.4378995464485,
#      'y': 579.2680207527111}],
#    'class': 'image',
#    'filename': 'train/YFT/img_02038.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 116.06540232997651,
#      'width': 190.6183614908373,
#      'x': 446.8941586062963,
#      'y': 463.4144166021689}],
#    'class': 'image',
#    'filename': 'train/YFT/img_02053.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 263.05333885735547,
#      'width': 256.275797115459,
#      'x': 755.0605096831499,
#      'y': 658.4805398611256}],
#    'class': 'image',
#    'filename': 'train/YFT/img_02055.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 140.21039478548255,
#      'width': 250.7690444501682,
#      'x': 255.42860439772198,
#      'y': 425.07894612456715}],
#    'class': 'image',
#    'filename': 'train/YFT/img_02067.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 270.25447695812045,
#      'width': 498.57291438825655,
#      'x': 796.149356493397,
#      'y': 338.4534907359533}],
#    'class': 'image',
#    'filename': 'train/YFT/img_02075.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 130.4676785315064,
#      'width': 196.9723068738652,
#      'x': 515.728566922432,
#      'y': 461.72003116669475},
#     {'class': 'YFT',
#      'height': 123.69013678961005,
#      'width': 64.38664654801615,
#      'x': 154.61267098701248,
#      'y': 598.9652514400976}],
#    'class': 'image',
#    'filename': 'train/YFT/img_02104.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 228.74203378900478,
#      'width': 123.26654043074143,
#      'x': 891.0349408799473,
#      'y': 521.8707141260256}],
#    'class': 'image',
#    'filename': 'train/YFT/img_02111.jpg'},
#   {'annotations': [{'class': 'YFT',
#      'height': 272.7960551113316,
#      'width': 108.44066787034302,
#      'x': 415.5480280500253,
#      'y': 509.5864197188384}],
#    'class': 'image',
# ...
#   {'annotations': [{'class': 'BET',
#      'height': 186.38239790215204,
#      'width': 324.0512145344235,
#      'x': 895.2709044686325,
#      'y': 219.84651025276568}],
#    'class': 'image',
#    'filename': 'train/BET/img_05736.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 306.68376382081374,
#      'width': 236.79036460750683,
#      'x': 934.2417694845369,
#      'y': 408.34688994926034}],
#    'class': 'image',
#    'filename': 'train/BET/img_05748.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 156.7306527813551,
#      'width': 141.05758750321962,
#      'x': 323.8394163549891,
#      'y': 185.95880154328347}],
#    'class': 'image',
#    'filename': 'train/BET/img_05784.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 158.84863457569776,
#      'width': 127.07890766055817,
#      'x': 337.6062980182163,
#      'y': 165.41437813815992}],
#    'class': 'image',
#    'filename': 'train/BET/img_05796.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 192.31274692631138,
#      'width': 78.36532639067752,
#      'x': 577.573635317237,
#      'y': 423.5963588685273}],
#    'class': 'image',
#    'filename': 'train/BET/img_05797.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 311.34332376836755,
#      'width': 227.8948410712677,
#      'x': 928.0996222809433,
#      'y': 408.9822844875631}],
#    'class': 'image',
#    'filename': 'train/BET/img_05841.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 305.4129747442082,
#      'width': 234.24878645429567,
#      'x': 930.4294022547202,
#      'y': 410.67666992303725}],
#    'class': 'image',
#    'filename': 'train/BET/img_05848.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 233.40159373655854,
#      'width': 311.34332376836755,
#      'x': 625.016427510512,
#      'y': 572.4904790108146}],
#    'class': 'image',
#    'filename': 'train/BET/img_05858.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 158.42503821682922,
#      'width': 302.44780023212843,
#      'x': 973.0008363210072,
#      'y': 241.4499245550606}],
#    'class': 'image',
#    'filename': 'train/BET/img_05874.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 179.18125980138706,
#      'width': 347.34901427219245,
#      'x': 765.4386204754289,
#      'y': 175.15709439213606},
#     {'class': 'BET',
#      'height': 187.22959061988908,
#      'width': 336.75910530047923,
#      'x': 450.49472765667883,
#      'y': 255.8522007565905}],
#    'class': 'image',
#    'filename': 'train/BET/img_05974.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 468.0739765497226,
#      'width': 220.69370297050273,
#      'x': 347.13721609275814,
#      'y': 469.132967446894}],
#    'class': 'image',
#    'filename': 'train/BET/img_05986.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 110.98224602355413,
#      'width': 223.6588774825824,
#      'x': 505.3504561301531,
#      'y': 453.67170034819276}],
#    'class': 'image',
#    'filename': 'train/BET/img_06035.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 135.12723847906022,
#      'width': 394.7918064654675,
#      'x': 741.7172243787913,
#      'y': 248.01566811752275}],
#    'class': 'image',
#    'filename': 'train/BET/img_06277.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 121.99575135413585,
#      'width': 81.3305009027572,
#      'x': 659.1159343994285,
#      'y': 453.24810398932425}],
#    'class': 'image',
#    'filename': 'train/BET/img_06287.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 295.670258490232,
#      'width': 202.47905953915597,
#      'x': 917.5097133092302,
#      'y': 411.7356608202085}],
#    'class': 'image',
#    'filename': 'train/BET/img_06384.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 177.06327800704443,
#      'width': 332.9467380706624,
#      'x': 820.0825507694689,
#      'y': 118.18338412431913},
#     {'class': 'BET',
#      'height': 216.45773938181745,
#      'width': 156.30705642248657,
#      'x': 211.5863812548294,
#      'y': 300.54161661722014}],
#    'class': 'image',
#    'filename': 'train/BET/img_06453.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 86.41365720917958,
#      'width': 191.4655542085743,
#      'x': 423.5963588685273,
#      'y': 458.7548566546151}],
#    'class': 'image',
#    'filename': 'train/BET/img_06532.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 135.55083483792876,
#      'width': 380.38953026393756,
#      'x': 825.1657070758912,
#      'y': 251.61623716790524}],
#    'class': 'image',
#    'filename': 'train/BET/img_06542.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 150.80030375719576,
#      'width': 291.8578912604154,
#      'x': 660.1749252965999,
#      'y': 336.7591053004792}],
#    'class': 'image',
#    'filename': 'train/BET/img_06575.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 133.4328530435861,
#      'width': 263.05333885735547,
#      'x': 901.2012534927919,
#      'y': 163.29639634381726}],
#    'class': 'image',
#    'filename': 'train/BET/img_06613.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 85.5664644914425,
#      'width': 193.15993964404845,
#      'x': 437.5750387111887,
#      'y': 434.60986419910904}],
#    'class': 'image',
#    'filename': 'train/BET/img_06623.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 141.05758750321957,
#      'width': 381.6603193405431,
#      'x': 641.5366855063846,
#      'y': 264.5359261133953},
#     {'class': 'BET',
#      'height': 108.01707151147446,
#      'width': 299.4826257200489,
#      'x': 967.7058818351506,
#      'y': 361.9630886531566},
#     {'class': 'BET',
#      'height': 137.66881663227133,
#      'width': 317.27367279252695,
#      'x': 428.4677169955154,
#      'y': 367.893437677316}],
#    'class': 'image',
#    'filename': 'train/BET/img_06636.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 304.1421856676026,
#      'width': 264.7477242928296,
#      'x': 944.4080820973817,
#      'y': 395.21540282433597}],
#    'class': 'image',
#    'filename': 'train/BET/img_06772.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 215.61054666408035,
#      'width': 316.42648007478994,
#      'x': 608.072573155771,
#      'y': 562.32416639797}],
#    'class': 'image',
#    'filename': 'train/BET/img_06776.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 242.72071363166617,
#      'width': 513.8223833075236,
#      'x': 758.0256841952296,
#      'y': 142.96377111812797}],
#    'class': 'image',
#    'filename': 'train/BET/img_06777.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 320.2388473046067,
#      'width': 227.0476483535307,
#      'x': 885.7399863940907,
#      'y': 274.91403690567427}],
#    'class': 'image',
#    'filename': 'train/BET/img_06825.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 198.24309595047077,
#      'width': 321.0860400223437,
#      'x': 536.6965866864241,
#      'y': 401.99294456623244},
#     {'class': 'BET',
#      'height': 94.46198802768157,
#      'width': 360.05690503824815,
#      'x': 698.086799415333,
#      'y': 213.70436304917203},
#     {'class': 'BET',
#      'height': 104.20470428165771,
#      'width': 374.0355848809096,
#      'x': 608.4961695146394,
#      'y': 113.94742053563385},
#     {'class': 'BET',
#      'height': 235.94317188976976,
#      'width': 172.40371805949064,
#      'x': 210.31559217822382,
#      'y': 422.96096433022456},
#     {'class': 'BET',
#      'height': 222.38808840597684,
#      'width': 73.70576644312375,
#      'x': 104.20470428165771,
#      'y': 271.3134678552917},
#     {'class': 'BET',
#      'height': 62.26866475367352,
#      'width': 155.45986370474952,
#      'x': 110.34685148525136,
#      'y': 154.4008728075782},
#     {'class': 'BET',
#      'height': 169.86213990627945,
#      'width': 122.84294407187292,
#      'x': 83.44848269709988,
#      'y': 247.16847539978568}],
#    'class': 'image',
#    'filename': 'train/BET/img_06827.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 145.71714745077333,
#      'width': 365.5636577035391,
#      'x': 890.1877481622101,
#      'y': 472.3099401384079}],
#    'class': 'image',
#    'filename': 'train/BET/img_06862.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 84.29567541483692,
#      'width': 201.63186682141895,
#      'x': 504.503263412416,
#      'y': 477.6048946242645}],
#    'class': 'image',
#    'filename': 'train/BET/img_06867.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 175.3688925715703,
#      'width': 171.98012170062213,
#      'x': 673.9418069598269,
#      'y': 548.5572847347429},
#     {'class': 'BET',
#      'height': 112.25303510015976,
#      'width': 60.15068295933088,
#      'x': 723.0789845885761,
#      'y': 408.5586881286946}],
#    'class': 'image',
#    'filename': 'train/BET/img_06983.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 191.04195784970574,
#      'width': 79.21251910841465,
#      'x': 576.7264425994999,
#      'y': 422.1137716124874}],
#    'class': 'image',
#    'filename': 'train/BET/img_06997.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 108.8642642292115,
#      'width': 346.92541791332394,
#      'x': 693.2154412883449,
#      'y': 199.7256832065106},
#     {'class': 'BET',
#      'height': 246.10948450261435,
#      'width': 368.9524285744873,
#      'x': 557.2410100915477,
#      'y': 431.43289150759506},
#     {'class': 'BET',
#      'height': 249.07465901469402,
#      'width': 179.18125980138706,
#      'x': 214.9751521257776,
#      'y': 415.54802805002527},
#     {'class': 'BET',
#      'height': 225.77685927692502,
#      'width': 89.37883172125926,
#      'x': 110.34685148525136,
#      'y': 267.501100625475},
#     {'class': 'BET',
#      'height': 63.539453830279086,
#      'width': 166.47336903533122,
#      'x': 109.4996587675143,
#      'y': 158.4250382168292},
#     {'class': 'BET',
#      'height': 206.29142676897283,
#      'width': 144.44635837416783,
#      'x': 92.97940077164175,
#      'y': 236.15497006920398},
#     {'class': 'BET',
#      'height': 171.13292898288506,
#      'width': 219.4229138938971,
#      'x': 1025.950381179573,
#      'y': 199.93748138594492}],
#    'class': 'image',
#    'filename': 'train/BET/img_07007.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 437.15144235232026,
#      'width': 169.43854354741092,
#      'x': 299.05902936118025,
#      'y': 379.96593390506905}],
#    'class': 'image',
#    'filename': 'train/BET/img_07015.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 195.27792143839105,
#      'width': 127.07890766055823,
#      'x': 240.60273183732352,
#      'y': 367.893437677316}],
#    'class': 'image',
#    'filename': 'train/BET/img_07059.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 307.10736017968236,
#      'width': 264.3241279339611,
#      'x': 950.1266329421068,
#      'y': 407.7114954109576}],
#    'class': 'image',
#    'filename': 'train/BET/img_07164.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 185.9588015432835,
#      'width': 329.98156355858276,
#      'x': 447.52955314459905,
#      'y': 256.4875952948933},
#     {'class': 'BET',
#      'height': 173.67450713609622,
#      'width': 351.16138150200914,
#      'x': 769.0391895258114,
#      'y': 177.48687436591297}],
#    'class': 'image',
#    'filename': 'train/BET/img_07311.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 230.43641922447887,
#      'width': 307.1073601796823,
#      'x': 522.929705023197,
#      'y': 528.6482558679221}],
#    'class': 'image',
#    'filename': 'train/BET/img_07321.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 438.4222314289258,
#      'width': 193.15993964404848,
#      'x': 329.13437084084575,
#      'y': 510.22181425714115}],
#    'class': 'image',
#    'filename': 'train/BET/img_07378.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 185.11160882554645,
#      'width': 85.142868132574,
#      'x': 571.6432862930776,
#      'y': 420.8429825358819}],
#    'class': 'image',
#    'filename': 'train/BET/img_07410.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 223.2352811237139,
#      'width': 153.34188191040687,
#      'x': 211.79817943426366,
#      'y': 298.4236348228775},
#     {'class': 'BET',
#      'height': 115.64180597110797,
#      'width': 240.179135478455,
#      'x': 1107.0690839028962,
#      'y': 211.1627848959609}],
#    'class': 'image',
#    'filename': 'train/BET/img_07440.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 158.42503821682922,
#      'width': 465.95599475538006,
#      'x': 734.9396826368949,
#      'y': 261.3589534218814}],
#    'class': 'image',
#    'filename': 'train/BET/img_07518.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 160.96661637004036,
#      'width': 280.4207895709651,
#      'x': 829.4016706645765,
#      'y': 162.23740544664594},
#     {'class': 'BET',
#      'height': 221.96449204710834,
#      'width': 147.83512924511604,
#      'x': 207.77401402501266,
#      'y': 298.63543300231174}],
#    'class': 'image',
#    'filename': 'train/BET/img_07519.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 307.53095653855087,
#      'width': 451.5537185538501,
#      'x': 652.338392657532,
#      'y': 592.1877096982012}],
#    'class': 'image',
#    'filename': 'train/BET/img_07545.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 187.65318697875762,
#      'width': 337.6062980182162,
#      'x': 812.2460181304011,
#      'y': 129.83228399320365},
#     {'class': 'BET',
#      'height': 218.5757211761601,
#      'width': 153.76547826927543,
#      'x': 207.35041766614412,
#      'y': 302.02420387326}],
#    'class': 'image',
#    'filename': 'train/BET/img_07579.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 171.9801217006221,
#      'width': 414.70083533228825,
#      'x': 634.7591437644882,
#      'y': 268.5600915226463}],
#    'class': 'image',
#    'filename': 'train/BET/img_07581.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 449.4357367595075,
#      'width': 163.08459816438307,
#      'x': 403.05193546340377,
#      'y': 556.3938173738106}],
#    'class': 'image',
#    'filename': 'train/BET/img_07620.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 230.43641922447884,
#      'width': 390.1322465179136,
#      'x': 726.2559572800901,
#      'y': 194.85432507952254}],
#    'class': 'image',
#    'filename': 'train/BET/img_07721.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 175.3688925715703,
#      'width': 351.16138150200914,
#      'x': 770.7335749612854,
#      'y': 177.48687436591297},
#     {'class': 'BET',
#      'height': 189.77116877310021,
#      'width': 335.48831622387365,
#      'x': 454.09529670706127,
#      'y': 258.81737526867016}],
#    'class': 'image',
#    'filename': 'train/BET/img_07734.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 87.68444628578516,
#      'width': 255.00500803885336,
#      'x': 941.2311094058678,
#      'y': 165.41437813815992}],
#    'class': 'image',
#    'filename': 'train/BET/img_07795.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 174.52169985383324,
#      'width': 355.39734509069433,
#      'x': 768.1919968080742,
#      'y': 175.3688925715703},
#     {'class': 'BET',
#      'height': 190.19476513196872,
#      'width': 337.18270165934774,
#      'x': 450.2829294772446,
#      'y': 257.7583843714989}],
#    'class': 'image',
#    'filename': 'train/BET/img_07804.jpg'},
#   {'annotations': [{'class': 'BET',
#      'height': 105.89908971713186,
#      'width': 348.19620698992946,
#      'x': 691.7328540323051,
#      'y': 212.2217757931322},
#     {'class': 'BET',
#      'height': 239.33194276071794,
#      'width': 362.5984831914593,
#      'x': 557.0292119121134,
#      'y': 427.19692791890975},
#     {'class': 'BET',
#      'height': 228.3184374301362,
#      'width': 168.16775447080533,
#      'x': 206.9268213072756,
#      'y': 417.03061530606516},
#     {'class': 'BET',
#      'height': 94.4619880276816,
#      'width': 207.5622158455783,
#      'x': 917.9333096680987,
#      'y': 139.9985966060483},
#     {'class': 'BET',
#      'height': 213.0689685108692,
#      'width': 77.94173003180902,
#      'x': 108.44066787034299,
#      'y': 266.2303115488694},
#     {'class': 'BET',
#      'height': 65.65743562462174,
#      'width': 157.15424914022364,
#      'x': 110.7704478441199,
#      'y': 151.43569829549853},
#     {'class': 'BET',
#      'height': 199.09028866820785,
#      'width': 132.16206396698053,
#      'x': 92.34400623333896,
#      'y': 236.36676824863824}],
#    'class': 'image',
#    'filename': 'train/BET/img_07825.jpg'}]}

# %%
pd.DataFrame(
    [(k, len(v)) for k, v in boxes.items()],
    columns=['class', 'count'])
# Out:
#    class  count
# 0    yft    734
# 1    alb   1719
# 2    dol    117
# 3  other    299
# 4    lag     67
# 5  shark    176
# 6    bet    200

# %%
from matplotlib import pyplot as plt


annotation = boxes['lag'][0]
img = draw_boxes(annotation)

plt.figure(figsize=(6, 6), dpi=120)
plt.imshow(img)
plt.title('{} {}x{}'.format(
    annotation['filename'], img.shape[0], img.shape[1]));

# %% [markdown]
# ### Распределение размеров разметки

# %%
annotations = sum([box['annotations']
                   for box in sum(boxes.values(), [])], [])

widths = [rect['width'] for rect in annotations]
heights = [rect['height'] for rect in annotations]

plt.hist(widths)
plt.hist(heights);

# %% [markdown]
# # Экстрактор признаков

# %%
from tensorflow.keras.applications import vgg16

IMG_HEIGHT = 750
IMG_WIDTH = 1200

features = vgg16.VGG16(weights='imagenet',
                       include_top=False,
                       input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

# дообучаем последние 5 слоев
for layer in features.layers[:-5]:
    layer.trainable = False
    
feature_tensor = features.layers[-1].output
print(feature_tensor.shape)
# Out:
# (None, 23, 37, 512)

# %% [markdown]
# # Сетка якорей (anchor grid)

# %%
FEATURE_SHAPE = (feature_tensor.shape[1],
                 feature_tensor.shape[2])

GRID_STEP_H = IMG_HEIGHT / FEATURE_SHAPE[0]
GRID_STEP_W = IMG_WIDTH / FEATURE_SHAPE[1]

ANCHOR_WIDTH = 150.
ANCHOR_HEIGHT = 150. 

# сетка якорей, размер определяется соотношением 
# размера входного изображения и размером тензора признаков
ANCHOR_CENTERS = np.mgrid[GRID_STEP_H/2:IMG_HEIGHT:GRID_STEP_H,
                          GRID_STEP_W/2:IMG_WIDTH:GRID_STEP_W]

# %%
def iou(rect, x_scale, y_scale, anchor_x, anchor_y,
        anchor_w=ANCHOR_WIDTH, anchor_h=ANCHOR_HEIGHT):
    
    rect_x1 = (rect['x'] - rect['width'] / 2) * x_scale
    rect_x2 = (rect['x'] + rect['width'] / 2) * x_scale
    
    rect_y1 = (rect['y'] - rect['height'] / 2) * y_scale
    rect_y2 = (rect['y'] + rect['height'] / 2) * y_scale
    
    anch_x1, anch_x2 = anchor_x - anchor_w / 2, anchor_x + anchor_w / 2
    anch_y1, anch_y2 = anchor_y - anchor_h / 2, anchor_y + anchor_h / 2
    
    dx = (min(rect_x2, anch_x2) - max(rect_x1, anch_x1))
    dy = (min(rect_y2, anch_y2) - max(rect_y1, anch_y1))
    
    intersection = dx * dy if (dx > 0 and dy > 0) else 0.
    
    anch_square = (anch_x2 - anch_x1) * (anch_y2 - anch_y1)
    rect_square = (rect_x2 - rect_x1) * (rect_y2 - rect_y1)
    union = anch_square + rect_square - intersection
    
    return intersection / union

def encode_anchors(annotation, img_shape, iou_thr=0.5):
    encoded = np.zeros(shape=(FEATURE_SHAPE[0],
                              FEATURE_SHAPE[1], 5), dtype=np.float32)
    x_scale = 1. * IMG_WIDTH / img_shape[1]
    y_scale = 1. * IMG_HEIGHT / img_shape[0]
    for rect in annotation['annotations']:
        scores = []
        for row in range(FEATURE_SHAPE[0]):
            for col in range(FEATURE_SHAPE[1]):
                anchor_x = ANCHOR_CENTERS[1, row, col]
                anchor_y = ANCHOR_CENTERS[0, row, col]
                score = iou(rect, x_scale, y_scale, anchor_x, anchor_y)
                scores.append((score, anchor_x, anchor_y, row, col))
        
        scores = sorted(scores, reverse=True)
        if scores[0][0] < iou_thr:
            scores = [scores[0]]  # default anchor
        else:
            scores = [e for e in scores if e[0] > iou_thr]

        for score, anchor_x, anchor_y, row, col in scores:
            dx = (anchor_x - rect['x'] * x_scale) / ANCHOR_WIDTH
            dy = (anchor_y - rect['y'] * y_scale) / ANCHOR_HEIGHT
            dw = (ANCHOR_WIDTH - rect['width'] * x_scale) / ANCHOR_WIDTH
            dh = (ANCHOR_HEIGHT - rect['height'] * y_scale) / ANCHOR_HEIGHT
            encoded[row, col] = [1., dx, dy, dw, dh]
            
    return encoded

def _sigmoid(x):
    return 1. / (1. + np.exp(-x))

def decode_prediction(prediction, conf_thr=0.1):
    rectangles = []
    for row in range(FEATURE_SHAPE[0]):
        for col in range(FEATURE_SHAPE[1]):
            logit, dx, dy, dw, dh = prediction[row, col]
            conf = _sigmoid(logit)
            if conf > conf_thr:
                anchor_x = ANCHOR_CENTERS[1, row, col]
                anchor_y = ANCHOR_CENTERS[0, row, col]
                rectangles.append({'x': anchor_x - dx * ANCHOR_WIDTH,
                                   'y': anchor_y - dy * ANCHOR_HEIGHT,
                                   'width': ANCHOR_WIDTH - dw * ANCHOR_WIDTH,
                                   'height': ANCHOR_HEIGHT - dh * ANCHOR_HEIGHT,
                                   'conf': conf})
    return rectangles

def non_max_suppression(rectangles, max_output_size, iou_threshold=0.5):
    if not rectangles:
        return rectangles
    
    boxes = [[r['y'],
              r['x'],
              r['y'] + r['height'],
              r['x'] + r['width']] for r in rectangles]
    scores = [r['conf'] for r in rectangles]
    indices = tf.image.non_max_suppression(np.array(boxes),
                                           np.array(scores),
                                           max_output_size,
                                           iou_threshold)
    
    return [rectangles[i] for i in indices]

# %% [markdown]
# ### Валидация энкодинга/декодинга якорей

# %%
annotation = boxes['lag'][0]

encoded = encode_anchors(annotation,
                         img_shape=(IMG_HEIGHT, IMG_WIDTH),
                         iou_thr=0.5)

decoded = decode_prediction(encoded, conf_thr=0.7)
decoded = sorted(decoded, key = lambda e: -e['conf'])

plt.figure(figsize=(6, 6), dpi=120)
plt.imshow(draw_boxes(annotation, decoded))
plt.title('{} {}x{}'.format(
    annotation['filename'], img.shape[0], img.shape[1]));

# %% [markdown]
# ## Функция потерь

# %%
K = tf.keras.backend

def confidence_loss(y_true, y_pred):
    conf_loss = K.binary_crossentropy(y_true[..., 0], 
                                      y_pred[..., 0],
                                      from_logits=True)
    return conf_loss

def smooth_l1(y_true, y_pred):
    abs_loss = K.abs(y_true[..., 1:] - y_pred[..., 1:])
    square_loss = 0.5 * K.square(y_true[..., 1:] - y_pred[..., 1:])
    mask = K.cast(K.greater(abs_loss, 1.), 'float32')
    total_loss = (abs_loss - 0.5) * mask + 0.5 * square_loss * (1. - mask)
    return K.sum(total_loss, axis=-1)

def total_loss(y_true, y_pred, neg_pos_ratio=3):
    batch_size = K.shape(y_true)[0]
    
    # TODO: добавьте функцию потерь для классификации детекции
    
    y_true = K.reshape(y_true, (batch_size, -1, 5))
    y_pred = K.reshape(y_pred, (batch_size, -1, 5))

    # confidence loss
    conf_loss = confidence_loss(y_true, y_pred)
    
    # smooth l1 loss
    loc_loss = smooth_l1(y_true, y_pred)
    
    # positive examples loss
    pos_conf_loss = K.sum(conf_loss * y_true[..., 0], axis=-1)
    pos_loc_loss = K.sum(loc_loss * y_true[..., 0], axis=-1)
    
    # negative examples loss
    anchors = K.shape(y_true)[1]
    num_pos = K.sum(y_true[..., 0], axis=-1)
    num_pos_avg = K.mean(num_pos)
    num_neg = K.min([neg_pos_ratio * (num_pos_avg) + 1., K.cast(anchors, 'float32')])
    
    # hard negative mining
    neg_conf_loss, _ = tf.nn.top_k(conf_loss * (1. - y_true[..., 0]),
                                   k=K.cast(num_neg, 'int32'))

    neg_conf_loss = K.sum(neg_conf_loss, axis=-1)
    
    # total conf loss
    total_conf_loss = (neg_conf_loss + pos_conf_loss) / (num_neg + num_pos + 1e-32)
    loc_loss = pos_loc_loss / (num_pos + 1e-32)
    
    return total_conf_loss + 0.5 * loc_loss

# %% [markdown]
# ## Загрузка данных

# %%
from random import shuffle

def load_img(path, target_size=(IMG_WIDTH, IMG_HEIGHT)):
    img = cv2.imread(path, cv2.IMREAD_COLOR)[...,::-1]
    img_shape = img.shape
    img_resized = cv2.resize(img, target_size)
    return img_shape, vgg16.preprocess_input(img_resized.astype(np.float32))

def data_generator(boxes, batch_size=32):
    boxes = sum(boxes.values(), [])
    while True:
        shuffle(boxes)
        for i in range(len(boxes)//batch_size):
            X, y = [], []
            for j in range(i*batch_size,(i+1)*batch_size):
                img_shape, img = load_img(boxes[j]['filename'])
                # TODO: добавьте one-hot encoding в разметку для классов
                y.append(encode_anchors(boxes[j], img_shape))
                X.append(img)
            yield np.array(X), np.array(y)

# %% [markdown]
# ## Добавляем выход детектора

# %%
output = tf.keras.layers.BatchNormalization()(feature_tensor)

# TODO: добавьте выходы для классификации детекции
output = tf.keras.layers.Conv2D(5,
                                kernel_size=(1, 1), 
                                activation='linear',
                                kernel_regularizer='l2')(output)

model = tf.keras.models.Model(inputs=features.inputs, outputs=output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 750, 1200, 3)]    0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 750, 1200, 64)     1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 750, 1200, 64)     36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 375, 600, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 375, 600, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 375, 600, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 187, 300, 128)     0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 187, 300, 256)     295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 187, 300, 256)     590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 187, 300, 256)     590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 93, 150, 256)      0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 93, 150, 512)      1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 93, 150, 512)      2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 93, 150, 512)      2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 46, 75, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 46, 75, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 46, 75, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 46, 75, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 23, 37, 512)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 23, 37, 512)       2048
# _________________________________________________________________
# conv2d (Conv2D)              (None, 23, 37, 5)         2565
# =================================================================
# Total params: 14,719,301
# Trainable params: 11,802,629
# Non-trainable params: 2,916,672
# _________________________________________________________________

# %% [markdown]
# ## Обучение

# %%
adam = tf.keras.optimizers.Adam(lr=3e-4, decay=1e-6)
model.compile(optimizer=adam, 
              loss=total_loss,
              metrics=[confidence_loss])

# %% [raw]
# batch_size = 5
#
# gen = data_generator(boxes, batch_size=batch_size)
# steps_per_epoch = sum(map(len, boxes.values()), 0) / batch_size
#
# checkpoint = tf.keras.callbacks.ModelCheckpoint(
#     'fishdetector.hdf5',
#     monitor='loss',
#     verbose=1,
#     save_best_only=True,
#     save_weights_only=False,
#     mode='auto',
#     save_freq=10)
#
# model.fit(gen,
#           steps_per_epoch=steps_per_epoch,
#           epochs=100,
#           callbacks=[checkpoint])

# %% [markdown]
# ## Результат работы детектора

# %%
model.load_weights('fishdetector.hdf5')

# %%
model.__dict__
# Out:
# {'_self_setattr_tracking': True,
#  '_is_model_for_instrumentation': True,
#  '_instrumented_keras_api': True,
#  '_instrumented_keras_layer_class': False,
#  '_instrumented_keras_model_class': True,
#  '_trainable': True,
#  '_stateful': False,
#  'built': True,
#  '_build_input_shape': TensorShape([None, 750, 1200, 3]),
#  '_saved_model_inputs_spec': TensorSpec(shape=(None, 750, 1200, 3), dtype=tf.float32, name='input_1'),
#  '_input_spec': None,
#  '_supports_masking': True,
#  '_name': 'model',
#  '_activity_regularizer': None,
#  '_trainable_weights': [],
#  '_non_trainable_weights': [],
#  '_updates': [],
#  '_thread_local': <_thread._local at 0x183c6a720>,
#  '_callable_losses': [],
#  '_losses': [],
#  '_metrics': [],
#  '_metrics_lock': <unlocked _thread.lock object at 0x183c4e180>,
#  '_dtype_policy': <Policy "float32">,
#  '_compute_dtype_object': tf.float32,
#  '_autocast': False,
#  '_layers': [<tensorflow.python.keras.engine.input_layer.InputLayer at 0x183b044f0>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183a7d310>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183a7da30>,
#   <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x183a7d790>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b63ee0>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b6ddc0>,
#   <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x183b6dc40>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b763d0>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b7c130>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b7c640>,
#   <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x183b7c280>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b87460>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b87a30>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b82910>,
#   <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x183a7daf0>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b745b0>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b749a0>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b82820>,
#   <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x183b74ee0>,
#   <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x183c45880>,
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183c45250>],
#  '_inbound_nodes_value': [],
#  '_outbound_nodes_value': [],
#  '_expects_training_arg': True,
#  '_default_training_arg': None,
#  '_expects_mask_arg': True,
#  '_dynamic': False,
#  '_initial_weights': None,
#  '_auto_track_sub_layers': True,
#  '_preserve_input_structure_in_config': False,
#  '_is_graph_network': True,
#  'inputs': [<KerasTensor: shape=(None, 750, 1200, 3) dtype=float32 (created by layer 'input_1')>],
#  'outputs': [<KerasTensor: shape=(None, 23, 37, 5) dtype=float32 (created by layer 'conv2d')>],
#  'input_names': ['input_1'],
#  'output_names': ['conv2d'],
#  'stop_training': False,
#  '_compute_output_and_mask_jointly': True,
#  '_distribution_strategy': None,
#  'train_function': None,
#  'test_function': None,
#  '_compiled_trainable_state': <WeakKeyDictionary at 0x183c3b730>,
#  '_training_state': None,
#  '_trackable_saver': <tensorflow.python.training.tracking.util.TrackableSaver at 0x183c6b7f0>,
#  '_steps_per_execution': <tf.Variable 'Variable:0' shape=() dtype=int64, numpy=1>,
#  '_train_counter': <tf.Variable 'Variable:0' shape=() dtype=int64, numpy=0>,
#  '_test_counter': <tf.Variable 'Variable:0' shape=() dtype=int64, numpy=0>,
#  '_predict_counter': <tf.Variable 'Variable:0' shape=() dtype=int64, numpy=1>,
#  '_base_model_initialized': True,
#  '_nested_inputs': <KerasTensor: shape=(None, 750, 1200, 3) dtype=float32 (created by layer 'input_1')>,
#  '_nested_outputs': <KerasTensor: shape=(None, 23, 37, 5) dtype=float32 (created by layer 'conv2d')>,
#  '_enable_dict_to_input_mapping': True,
#  '_input_layers': [<tensorflow.python.keras.engine.input_layer.InputLayer at 0x183b044f0>],
#  '_output_layers': [<tensorflow.python.keras.layers.convolutional.Conv2D at 0x183c45250>],
#  '_input_coordinates': [(<tensorflow.python.keras.engine.input_layer.InputLayer at 0x183b044f0>,
#    0,
#    0)],
#  '_output_coordinates': [(<tensorflow.python.keras.layers.convolutional.Conv2D at 0x183c45250>,
#    0,
#    0)],
#  '_output_mask_cache': {},
#  '_output_tensor_cache': {},
#  '_output_shape_cache': {},
#  '_network_nodes': {'batch_normalization_ib-0',
#   'block1_conv1_ib-0',
#   'block1_conv2_ib-0',
#   'block1_pool_ib-0',
#   'block2_conv1_ib-0',
#   'block2_conv2_ib-0',
#   'block2_pool_ib-0',
#   'block3_conv1_ib-0',
#   'block3_conv2_ib-0',
#   'block3_conv3_ib-0',
#   'block3_pool_ib-0',
#   'block4_conv1_ib-0',
#   'block4_conv2_ib-0',
#   'block4_conv3_ib-0',
#   'block4_pool_ib-0',
#   'block5_conv1_ib-0',
#   'block5_conv2_ib-0',
#   'block5_conv3_ib-0',
#   'block5_pool_ib-0',
#   'conv2d_ib-0',
#   'input_1_ib-0'},
#  '_nodes_by_depth': defaultdict(list,
#              {0: [<tensorflow.python.keras.engine.node.Node at 0x183c2a910>],
#               1: [<tensorflow.python.keras.engine.node.Node at 0x183bed2e0>],
#               2: [<tensorflow.python.keras.engine.node.Node at 0x183b63b20>],
#               3: [<tensorflow.python.keras.engine.node.Node at 0x183b95df0>],
#               4: [<tensorflow.python.keras.engine.node.Node at 0x183b829a0>],
#               5: [<tensorflow.python.keras.engine.node.Node at 0x183b749d0>],
#               6: [<tensorflow.python.keras.engine.node.Node at 0x183b746a0>],
#               7: [<tensorflow.python.keras.engine.node.Node at 0x183a7d880>],
#               8: [<tensorflow.python.keras.engine.node.Node at 0x183b822b0>],
#               9: [<tensorflow.python.keras.engine.node.Node at 0x183b873d0>],
#               10: [<tensorflow.python.keras.engine.node.Node at 0x183b87550>],
#               11: [<tensorflow.python.keras.engine.node.Node at 0x183b71160>],
#               12: [<tensorflow.python.keras.engine.node.Node at 0x183b63cd0>],
#               13: [<tensorflow.python.keras.engine.node.Node at 0x183b76b50>],
#               14: [<tensorflow.python.keras.engine.node.Node at 0x183b764c0>],
#               15: [<tensorflow.python.keras.engine.node.Node at 0x183b639d0>],
#               16: [<tensorflow.python.keras.engine.node.Node at 0x183b6dd00>],
#               17: [<tensorflow.python.keras.engine.node.Node at 0x183b63fd0>],
#               18: [<tensorflow.python.keras.engine.node.Node at 0x183b31f10>],
#               19: [<tensorflow.python.keras.engine.node.Node at 0x183a7db20>],
#               20: [<tensorflow.python.keras.engine.node.Node at 0x183b19f40>]}),
#  '_layer_call_argspecs': {<tensorflow.python.keras.engine.input_layer.InputLayer at 0x183b044f0>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw='kwargs', defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183a7d310>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183a7da30>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x183a7d790>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b63ee0>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b6ddc0>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x183b6dc40>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b763d0>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b7c130>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b7c640>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x183b7c280>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b87460>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b87a30>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b82910>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x183a7daf0>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b745b0>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b749a0>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183b82820>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x183b74ee0>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x183c45880>: FullArgSpec(args=['self', 'inputs', 'training'], varargs=None, varkw=None, defaults=(None,), kwonlyargs=[], kwonlydefaults=None, annotations={}),
#   <tensorflow.python.keras.layers.convolutional.Conv2D at 0x183c45250>: FullArgSpec(args=['self', 'inputs'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={})},
#  '_feed_input_names': ['input_1'],
#  '_feed_inputs': [<KerasTensor: shape=(None, 750, 1200, 3) dtype=float32 (created by layer 'input_1')>],
#  '_feed_input_shapes': [(None, 750, 1200, 3)],
#  '_tensor_usage_count': Counter({'6503780704': 1,
#           '6504518464': 1,
#           '6504724272': 1,
#           '6504764992': 1,
#           '6504726432': 1,
#           '6504782816': 1,
#           '6504803056': 1,
#           '6504827344': 1,
#           '6504801088': 1,
#           '6504852592': 1,
#           '6504872832': 1,
#           '6504870288': 1,
#           '6504764560': 1,
#           '6504893888': 1,
#           '6504795344': 1,
#           '6504893936': 1,
#           '6504930032': 1,
#           '6504935184': 1,
#           '6504931824': 1,
#           '6505686928': 1,
#           '6505804800': 1}),
#  '_obj_reference_counts_dict': ObjectIdentityDictionary({<_ObjectIdentityWrapper wrapping <tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x183c45e50>>: 1, <_ObjectIdentityWrapper wrapping <tensorflow.python.keras.engine.compile_utils.LossesContainer object at 0x183aec0d0>>: 1, <_ObjectIdentityWrapper wrapping <tensorflow.python.keras.engine.compile_utils.MetricsContainer object at 0x183c45eb0>>: 1, <_ObjectIdentityWrapper wrapping True>: 1, <_ObjectIdentityWrapper wrapping <function total_loss at 0x183c2f040>>: 1, <_ObjectIdentityWrapper wrapping <tensorflow.python.eager.def_function.Function object at 0x183c3bf40>>: 1, <_ObjectIdentityWrapper wrapping <tensorflow.python.keras.callbacks.History object at 0x1847494f0>>: 1}),
#  '_run_eagerly': None,
#  '_self_unconditional_checkpoint_dependencies': [TrackableReference(name='optimizer', ref=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x183c45e50>)],
#  '_self_unconditional_dependency_names': {'optimizer': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x183c45e50>},
#  '_self_unconditional_deferred_dependencies': {},
#  '_self_update_uid': -1,
#  '_self_name_based_restores': set(),
#  '_self_saveable_object_factories': {},
#  'optimizer': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x183c45e50>,
#  'compiled_loss': <tensorflow.python.keras.engine.compile_utils.LossesContainer at 0x183aec0d0>,
#  'compiled_metrics': <tensorflow.python.keras.engine.compile_utils.MetricsContainer at 0x183c45eb0>,
#  '_is_compiled': True,
#  'loss': <function __main__.total_loss(y_true, y_pred, neg_pos_ratio=3)>,
#  'history': <tensorflow.python.keras.callbacks.History at 0x1847494f0>,
#  'predict_function': <tensorflow.python.eager.def_function.Function at 0x183c3bf40>}

# %%
annotation = boxes['lag'][5]

_, sample_img = load_img(annotation['filename'])
pred = model.predict(np.array([sample_img,]))

decoded = decode_prediction(pred[0], conf_thr=0.2)
decoded = non_max_suppression(decoded,
                              max_output_size=5,
                              iou_threshold=0.1)
print(decoded)

plt.figure(figsize=(6, 6), dpi=120)
img = draw_boxes(annotation, decoded, (IMG_WIDTH, IMG_HEIGHT))
plt.imshow(img)
plt.title('Предсказание модели {}x{}'.format(*img.shape));
# Out:
# [{'x': 1024.2945233712326, 'y': 531.4754569336125, 'width': 236.78418695926666, 'height': 241.07942283153534, 'conf': 0.22071306728724255}, {'x': 367.1347382503587, 'y': 561.6493594711242, 'width': 328.86528968811035, 'height': 177.27735042572021, 'conf': 0.20525750976872228}, {'x': 171.28527965900062, 'y': 96.27971017490263, 'width': 136.98338381946087, 'height': 215.57506173849106, 'conf': 0.20495358509132797}, {'x': 805.9473258820741, 'y': 148.14083694034946, 'width': 244.4576472043991, 'height': 167.8785301744938, 'conf': 0.20392585707681074}, {'x': 926.7869103800607, 'y': 606.6522923622119, 'width': 127.33113169670105, 'height': 197.56392985582352, 'conf': 0.20167054191591977}]

# %%
def decode_prediction_2(prediction, conf_thr=0.1):
    rectangles = []
    for row in range(FEATURE_SHAPE[0]):
        for col in range(FEATURE_SHAPE[1]):
            logit, dx, dy, dw, dh = prediction[row, col]
            conf = _sigmoid(logit)
            if conf > conf_thr:
                anchor_x = ANCHOR_CENTERS[1, row, col]
                anchor_y = ANCHOR_CENTERS[0, row, col]
                rectangles.append({'x': anchor_x - dx * ANCHOR_WIDTH,
                                   'y': anchor_y - dy * ANCHOR_HEIGHT,
                                   'width': ANCHOR_WIDTH - dw * ANCHOR_WIDTH,
                                   'height': ANCHOR_HEIGHT - dh * ANCHOR_HEIGHT,
                                   'conf': conf})
    return rectangles

# %%
y_proba = model.predict(np.array([sample_img,]))[0]

row, col = 0, 0
logit, dx, dy, dw, dh = y_proba[row, col]
_sigmoid(logit)
# Out:
# 0.14088679964870202

# %%
pred = model.predict(np.array([sample_img,]))
print(pred.shape)
decoded = decode_prediction(pred[0], conf_thr=0.0)
decoded = non_max_suppression(decoded,
                                  max_output_size=1,
                                  iou_threshold=0.1)
decoded
# Out:
# (1, 23, 37, 5)
# [{'x': 321.33965416735896,
#   'y': 255.42867235515428,
#   'width': 125.65902024507523,
#   'height': 232.51477181911469,
#   'conf': 0.20752195236593254}]

# %% [markdown]
# ## Визуализируем предсказание на тесте

# %%
test_images = glob('test_stg1/*.jpg')[5:10]


plt.figure(figsize=(6, 4 * len(test_images)), dpi=120)

for i, filename in enumerate(test_images):
    _, sample_img = load_img(filename)
    pred = model.predict(np.array([sample_img,]))

    decoded = decode_prediction(pred[0], conf_thr=0.0)
    decoded = non_max_suppression(decoded,
                                  max_output_size=2,
                                  iou_threshold=0.1)
    print(decoded)
    
    plt.subplot(len(test_images), 1, i + 1)
    img = draw_boxes({'filename': filename}, decoded, (IMG_WIDTH, IMG_HEIGHT))
    plt.imshow(img)
    plt.title('Предсказание на тесте {}'.format(filename));
# Out:
# [{'x': 845.8244112697809, 'y': 378.20449182763696, 'width': 164.64416719973087, 'height': 177.3743972182274, 'conf': 0.23838024576847477}, {'x': 1040.7900439927707, 'y': 313.58687263387054, 'width': 129.52945455908775, 'height': 219.25049722194672, 'conf': 0.23447566621984978}]
# [{'x': 766.2856636820613, 'y': 347.28497569651705, 'width': 39.416590332984924, 'height': 201.27266496419907, 'conf': 0.2495508826166554}, {'x': 900.4081856962798, 'y': 125.87585264573927, 'width': 212.7868965268135, 'height': 231.78978860378265, 'conf': 0.23626840150436973}]
# [{'x': 522.35352562086, 'y': 454.1315662148206, 'width': 197.50953912734985, 'height': 110.52404344081879, 'conf': 0.2928621457307404}, {'x': 838.9593046661971, 'y': 78.04313951131442, 'width': 266.0304397344589, 'height': 149.89226687466726, 'conf': 0.19224372500817916}]
# [{'x': 618.0358909070493, 'y': 580.5877019529757, 'width': 115.413299202919, 'height': 190.61208218336105, 'conf': 0.29920069839823665}, {'x': 775.587733633615, 'y': 666.8054271772828, 'width': 178.14489975571632, 'height': 214.41136300563812, 'conf': 0.26665166303496135}]
# [{'x': 1206.0008414693782, 'y': 625.1384112821974, 'width': 176.71905755996704, 'height': 198.00023585557938, 'conf': 0.23130471995076446}, {'x': 807.000886407253, 'y': 168.79621922321942, 'width': 147.05688413232565, 'height': 244.3380206823349, 'conf': 0.2280081824759546}]

# %% [markdown]
# ## Агрегация результатов

# %% [raw]
# from tensorflow.keras.models import load_model
# import os
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# import numpy as np
#
#
# img_width = 299
# img_height = 299
# batch_size = 32
# nbr_test_samples = 1000
#
# FishNames = ['ALB', 'BET', 'DOL', 'LAG', 'NoF', 'OTHER', 'SHARK', 'YFT']
#
# test_data_dir = 'test_stg1'
#
# # test data generator for prediction
# test_datagen = ImageDataGenerator(rescale=1./255)
#
# test_generator = test_datagen.flow_from_directory(
#         test_data_dir,
#         target_size=(img_width, img_height),
#         batch_size=batch_size,
#         shuffle = False, # Important !!!
#         classes = None,
#         class_mode = None)
#
# test_image_list = test_generator.filenames
#
# print('Loading model and weights from training process ...')
# InceptionV3_model = load_model('fishdetector.hdf5')
#
# print('Begin to predict for testing data ...')
# predictions = InceptionV3_model.predict_generator(test_generator, nbr_test_samples)
#
# np.savetxt('predictions.txt', predictions)
#
#
# print('Begin to write submission file ..')
# f_submit = open('submit.csv', 'w')
# f_submit.write('image,ALB,BET,DOL,LAG,NoF,OTHER,SHARK,YFT\n')
# for i, image_name in enumerate(test_image_list):
#     pred = ['%.6f' % p for p in predictions[i, :]]
#     if i % 100 == 0:
#         print('{} / {}'.format(i, nbr_test_samples))
#     f_submit.write('%s,%s\n' % (os.path.basename(image_name), ','.join(pred)))
#
# f_submit.close()
#
# print('Submission file successfully generated!')

# %%
# TODO: предскажите класс рыбы для фотографии из тестовой выборки
#
# Подготовьте файл с предсказаниями вероятностей для каждой фотографии:
# image,ALB,BET,DOL,LAG,NoF,OTHER,SHARK,YFT
# img_00001.jpg,1,0,0,0,0,...,0
# img_00002.jpg,0.3,0.1,0.6,0,...,0
